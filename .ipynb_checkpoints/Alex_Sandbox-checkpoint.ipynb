# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from astropy.time import Time

sns.set_context("talk")
sns.set_style("white")
sns.set_palette("Dark2")

# %%
data = pd.read_csv("data/2020oi_data.snana.txt", delimiter='\t')
data = data[data['MJD'] > 57000]
data = data[data['MAG'] > 0]

# %%
plt.figure(figsize=(10,8))
plt.plot(data['MJD'], data['MAG'], 'o')
plt.gca().invert_yaxis()

# %%
optical_df = pd.DataFrame({'time':MJD, 'mag':mag, 'err':err, 'band':bands})
#cut out whatever value went wrong
optical_df = optical_df[optical_df['time'] > 55000]
optical_df = optical_df[optical_df['mag'] > 0]

# %%
optical_df.to_csv("./data/2020oi_data.csv", index=False)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='time', y='mag', hue='band',data=optical_df, legend=False);
plt.gca().invert_yaxis()

# %%
#okay, so clearly lots of data, most of it useful. 
#let's fit one band - which has the most data?

# %%
from collections import Counter
Counter(optical_df['band'])
# Out:
# Counter({'ZTF-Cam - r-ZTF': 23,
#          'ZTF-Cam - g-ZTF': 22,
#          'Sinistro - up': 69,
#          'Sinistro - ip': 84,
#          'Sinistro - gp': 85,
#          'Sinistro - rp': 81,
#          'ACAM1 - orange': 1,
#          'UVOT - UVW2': 8,
#          'UVOT - U': 2,
#          'UVOT - UVW1': 10,
#          'UVOT - UVM2': 6,
#          'GPC1 - i': 2,
#          'Direct/4Kx4K - g': 22,
#          'Direct/4Kx4K - r': 24,
#          'Direct/4Kx4K - B': 24,
#          'Direct/4Kx4K - i': 23,
#          'Direct/4Kx4K - V': 25,
#          'Direct/4Kx4K - u': 18,
#          'Gaia-Photometric - G': 1,
#          'GPC1 - r': 2,
#          'GPC1 - g': 2,
#          'GPC1 - z': 1,
#          'Direct/2Kx2K - i': 10,
#          'Direct/2Kx2K - r': 10,
#          'Direct/2Kx2K - V': 5,
#          'Direct/2Kx2K - B': 6})

# %%
oneBand = optical_df[optical_df['band'] == 'Sinistro - rp']
oneBand.sort_values(by=['time'], inplace=True)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='time', y='mag',data=oneBand);
plt.gca().invert_yaxis()

# %%
oneBand.drop_duplicates(subset=['time', 'band'], inplace=True)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#let's fit a quadratic to the rise and a linear to the fall (rough start for now)
oneBand[oneBand['mag'] <14.2]
# Out:
#              time      mag       err           band
# 509  58864.311717  13.8804  0.031389  Sinistro - ip
# 99   58864.756285  14.0217  0.011351  Sinistro - ip
# 504  58867.303562  13.9908  0.008867  Sinistro - ip
# 111  58869.272646  14.1703  0.020063  Sinistro - ip

# %%
#get the points with lowest error
oneBand_clean = oneBand[oneBand['err'] < 1]

rise = oneBand_clean[oneBand_clean['time'] < 58864.311717]
peak = oneBand_clean[np.abs(oneBand_clean['time'] - 58864.311717) < 0.2]
#taking the point with lower error
fall = oneBand_clean[oneBand_clean['time'] > 58864.311717]

# %%
plt.figure(figsize=(10,8))
plt.plot(rise['time'], rise['mag'], 'o')
plt.scatter(peak['time'], peak['mag'], marker='*', s=300, zorder=100, c='tab:green')
plt.plot(fall['time'], fall['mag'], 'o')
plt.xlabel("MJD",fontsize=16)
plt.ylabel("Magnitude",fontsize=16)
plt.gca().invert_yaxis()

# %%
import matplotlib.pyplot as plt
zRise = np.polyfit(rise['time'].values.astype(float), rise['mag'].values, 2)
zFall = np.polyfit(fall['time'].values.astype(float), fall['mag'].values, 2)

# %%
def fit(time):
    PT = peak['time'].values
    time = np.array(time)
    riseTimes = time[time <= PT]
    fallTimes = time[time > PT]
    riseMag = zRise[2] + zRise[1]*riseTimes + zRise[0]*riseTimes**2
    fallMag = zFall[2] + zFall[1]*fallTimes + zFall[0]*fallTimes**2 #+ zFall[0]*fallTimes**3
    
    mag = np.concatenate([riseMag, fallMag])
    #mag = riseMag
    return mag

# %%
newTime = np.linspace(58850, 58910,num=100)
plt.figure(figsize=(10,8))
plt.plot(oneBand['time'].values, oneBand['mag'].values, 'o', label='Noisy Data');
plt.plot(newTime, fit(newTime), '--',label='Mean Model');
plt.plot(rise['time'].values, rise['mag'].values, 'o', label='Rise Data');
plt.plot(fall['time'].values, fall['mag'].values, 'o', label='Decline Data');
plt.plot(peak['time'].values, peak['mag'].values, '*', markersize=20, label='Peak');
plt.gca().invert_yaxis()
plt.xlabel("MJD",fontsize=16)
plt.ylabel("Magnitude",fontsize=16)
plt.legend(fontsize=16);

# %%
import george
from george.modeling import Model

class MeanModel(Model):
    parameter_names = ('r1', 'r2', 'r3', 'f1', 'f2', 'f3')
    def get_parameter_vector(self):
        return np.array([self.r1, self.r2, self.r3, self.f1, self.f2, self.f3])
    def set_vector(self, vec):
        self.r1 = vec[0]
        self.r2 = vec[1]
        self.r3 = vec[2]
        self.f1 = vec[3]
        self.f2 = vec[4]
        self.f3 = vec[5]
        #k.set_parameter_vector(k.get_parameter_vector() + np.random.randn(2))
    def set_parameter_vector(self, vec): 
        return set_vector(self, vec)
    def get_value(self, time):
        PT = peak['time'].values
        time = np.array(time)
        riseTimes = time[time <= PT]
        fallTimes = time[time > PT]
        riseMag = self.r3 + self.r2*riseTimes + self.r1*riseTimes**2
        fallMag = self.f3 + self.f2*fallTimes + self.f1*fallTimes**2 
        soln = np.concatenate([riseMag, fallMag])
        return soln

# %%
p0 = np.concatenate([zRise, zFall])

# %%
p0
# Out:
# array([ 5.59512193e-03, -6.58960906e+02,  1.94021560e+07,  1.13991776e-03,
#        -1.34146356e+02,  3.94662353e+06])

# %%
def lnprob(p):
    #let's make them all flat priors - 
    logBoundL = np.array([1.e-4, -1.e3, 1.e7, 1.e-4, -1.e3, 1.e6])
    logBoundR = np.array([1.e-3, -1.e2, 5.e7, 1.e-3, -1.e2, 5.e6])
    for i in np.arange(6):
        if (p[i] < logBoundL[i]) or (p[i] > logBoundR[i]):
            return -np.inf
    # Update the kernel and compute the lnlikelihood.
    gp.set_parameter_vector(p)
    return gp.lnlikelihood(flux, quiet=True)

# %%
import scipy.optimize as op
from george import kernels

kernel = 10.0 * kernels.ExpSquaredKernel(1.0)

gp = george.GP(mean=MeanModel(r1=zRise[0], r2=zRise[1], r3=zRise[2], f1=zFall[0], f2=zFall[1], f3=zFall[2]), kernel=kernel)

# Define the objective function (negative log-likelihood in this case).
def nll(p):
    gp.set_parameter_vector(p)
    ll = gp.log_likelihood(oneBand_clean['mag'].values, quiet=True)
    return -ll if np.isfinite(ll) else 1e25

# And the gradient of the objective function.
def grad_nll(p):
    gp.set_parameter_vector(p)
    return -gp.grad_log_likelihood(oneBand_clean['mag'].values, quiet=True)

# You need to compute the GP once before starting the optimization.
gp.compute(oneBand_clean['time'].values)

# Run the optimization routine.
p0 = gp.get_parameter_vector()
results = op.minimize(nll, p0, jac=grad_nll, method="L-BFGS-B")

# Update the kernel and print the final log-likelihood.
gp.set_parameter_vector(results.x)

ypred2, cov = gp.predict(oneBand_clean['mag'].values, oneBand_clean['time'].values, return_cov=True)
std = np.sqrt(np.diag(cov))

# plot the data
plt.figure(figsize=(10,8))
plt.fill_between(oneBand_clean['time'].values, ypred2+std, ypred2-std, color="g", alpha=0.5, label='conditioned, optimized GP')
newTime = np.linspace(58850, 58910,num=100)
plt.plot(oneBand['time'].values, oneBand['mag'].values, 'o', label='All data');
plt.plot(newTime, fit(newTime), '--',label='Mean Model');
plt.plot(rise['time'].values, rise['mag'].values, 'o', label='Rise Data');
plt.plot(fall['time'].values, fall['mag'].values, 'o', label='Decline Data');
plt.plot(peak['time'].values, peak['mag'].values, '*', markersize=20, label='Peak');
plt.gca().invert_yaxis()
plt.xlabel("Time since first point",fontsize=16)
plt.ylabel("Magnitude",fontsize=16)
plt.legend(fontsize=16);
plt.legend(fontsize=16)

# %%
import os
from os import listdir
from os.path import isfile, join
from astropy.io import fits

#rough position of the supernova at the center of the image, in pixels: 
#2251, 2251
XSN = 2251
YSN = 2251

timeArr = []
fixed_optical_df = []
zpts = []
zpts00 = []
path = "/Users/alexgagliano/Documents/Research/2020oi/2020oi_photometry/"
files = [f for f in listdir(path) if isfile(join(path, f))]
#get the REAL photometry:
header_list = ['Xpos','Ypos','Mag','Mag_err','flux','flux_err', 'type', 'peakflux', 'sigx', 'sigxy', 'sigy', 'sky','chisqr','class','FWHM1','FWHM2','FWHM','angle','extendedness','flag','mask','Nmask','RA','Dec','pixchk_Npos','pixchk_Nneg','pixchk_Nmask','pixchk_Ntot','pixchk_Fpos','pixchk_Fneg']
dict_vals = {}
bands = []
for file in files:
    bands.append(file[7])
    hdul = fits.open("/Users/alexgagliano/Documents/Research/2020oi/2020oi_photometry/%s"%file)
    temp = pd.read_csv("/Users/alexgagliano/Documents/Research/2020oi/2020oi_photometry/%s"%file, names=header_list, skiprows=1, delim_whitespace=True)
    sub = temp[np.abs(temp['Xpos'] - XSN) + np.abs(temp['Xpos'] - YSN)  < 3]
    sub = sub[sub['peakflux'] == np.max(sub['peakflux'].values)]
    timeArr.append(hdul[0].header['MJD-OBS'])
    zpts.append(hdul[0].header['ZPTMAGAV'])
    if hdul[0].header['ZPTMAGAV'] < 1:
        print(file)
    zpts00.append(hdul[0].header['ZPTMAG00'])
    fixed_optical_df.append(sub)
# Out:
# WARNING: File may have been truncated: actual file length (9977707) is smaller than the expected size (9979200) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (3368806) is smaller than the expected size (3369600) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (2232570) is smaller than the expected size (2234880) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (363885) is smaller than the expected size (365760) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (7785271) is smaller than the expected size (7787520) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (6586360) is smaller than the expected size (6586560) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (149435) is smaller than the expected size (149760) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (5006978) is smaller than the expected size (5008320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (3640236) is smaller than the expected size (3640320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (2870746) is smaller than the expected size (2871360) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (764299) is smaller than the expected size (766080) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (680390) is smaller than the expected size (682560) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (707319) is smaller than the expected size (708480) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (1815323) is smaller than the expected size (1817280) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (26149) is smaller than the expected size (28800) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (180772) is smaller than the expected size (181440) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (209780) is smaller than the expected size (210240) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (10060068) is smaller than the expected size (10062720) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (2933683) is smaller than the expected size (2934720) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (3270901) is smaller than the expected size (3271680) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (8943001) is smaller than the expected size (8945280) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (10258203) is smaller than the expected size (10258560) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (46092) is smaller than the expected size (48960) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (60078) is smaller than the expected size (60480) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (2980303) is smaller than the expected size (2980800) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (232831) is smaller than the expected size (233280) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (1198642) is smaller than the expected size (1200960) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (545962) is smaller than the expected size (547200) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (1599315) is smaller than the expected size (1601280) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (2429151) is smaller than the expected size (2430720) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (2042205) is smaller than the expected size (2044800) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (6565122) is smaller than the expected size (6566400) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (4099442) is smaller than the expected size (4101120) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (5884729) is smaller than the expected size (5886720) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (8385892) is smaller than the expected size (8386560) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (7084419) is smaller than the expected size (7084800) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (4035469) is smaller than the expected size (4037760) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (7945592) is smaller than the expected size (7945920) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (9239038) is smaller than the expected size (9239040) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (932908) is smaller than the expected size (933120) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (10433546) is smaller than the expected size (10434240) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (8137511) is smaller than the expected size (8138880) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (6318554) is smaller than the expected size (6318720) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (6497523) is smaller than the expected size (6500160) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (2011902) is smaller than the expected size (2013120) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (7983668) is smaller than the expected size (7986240) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (260544) is smaller than the expected size (262080) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (3743317) is smaller than the expected size (3744000) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (81316) is smaller than the expected size (83520) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (379166) is smaller than the expected size (380160) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (454017) is smaller than the expected size (455040) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (200974) is smaller than the expected size (201600) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (308201) is smaller than the expected size (311040) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (318819) is smaller than the expected size (319680) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (674685) is smaller than the expected size (676800) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (82870) is smaller than the expected size (83520) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (9267528) is smaller than the expected size (9267840) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (3101515) is smaller than the expected size (3101760) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (227651) is smaller than the expected size (230400) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (5555540) is smaller than the expected size (5558400) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (7934196) is smaller than the expected size (7934400) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (3231792) is smaller than the expected size (3234240) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (2404028) is smaller than the expected size (2404800) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (549070) is smaller than the expected size (550080) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (8764550) is smaller than the expected size (8766720) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (4739690) is smaller than the expected size (4740480) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (3873594) is smaller than the expected size (3873600) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (40135) is smaller than the expected size (40320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (3263390) is smaller than the expected size (3265920) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (6910110) is smaller than the expected size (6912000) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (1289292) is smaller than the expected size (1290240) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (708096) is smaller than the expected size (708480) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (1582480) is smaller than the expected size (1584000) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (10679078) is smaller than the expected size (10681920) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (2010866) is smaller than the expected size (2013120) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (324258) is smaller than the expected size (325440) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (133375) is smaller than the expected size (135360) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (2779837) is smaller than the expected size (2782080) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (412836) is smaller than the expected size (414720) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (4035473) is smaller than the expected size (4037760) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (139332) is smaller than the expected size (141120) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (302502) is smaller than the expected size (305280) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (2779319) is smaller than the expected size (2782080) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (557876) is smaller than the expected size (558720) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (7270379) is smaller than the expected size (7272000) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (177146) is smaller than the expected size (178560) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (94266) is smaller than the expected size (95040) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (3357407) is smaller than the expected size (3358080) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (124569) is smaller than the expected size (126720) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (10710422) is smaller than the expected size (10710720) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (156685) is smaller than the expected size (158400) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (7927981) is smaller than the expected size (7928640) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (2836558) is smaller than the expected size (2836800) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (10066286) is smaller than the expected size (10068480) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (672613) is smaller than the expected size (673920) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (183621) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (8485348) is smaller than the expected size (8487360) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (7932383) is smaller than the expected size (7934400) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (1874891) is smaller than the expected size (1877760) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (904159) is smaller than the expected size (904320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (3660696) is smaller than the expected size (3663360) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (8063955) is smaller than the expected size (8064000) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (5079498) is smaller than the expected size (5080320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (6018114) is smaller than the expected size (6019200) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (9136992) is smaller than the expected size (9138240) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (138556) is smaller than the expected size (141120) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (8674677) is smaller than the expected size (8677440) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (233350) is smaller than the expected size (236160) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (170415) is smaller than the expected size (172800) [astropy.io.fits.file]
# 2020oi.i.ut200216.4071_stch_1_i.2020oitmpl.18.stk_1.diff.dcmp
# 2020oi.i.ut200120.1130_stch_1_i.2020oitmpl.18.stk_1.diff.dcmp
# WARNING: File may have been truncated: actual file length (522652) is smaller than the expected size (524160) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (1163677) is smaller than the expected size (1166400) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (7430441) is smaller than the expected size (7433280) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (523947) is smaller than the expected size (524160) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (5501150) is smaller than the expected size (5503680) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (893799) is smaller than the expected size (895680) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (9131556) is smaller than the expected size (9132480) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (10006457) is smaller than the expected size (10008000) [astropy.io.fits.file]
# 2020oi.r.ut200314.3141_stch_1_r.2020oitmpl.19.stk_1.diff.dcmp
# 2020oi.i.ut200301.8104_stch_1_i.2020oitmpl.18.stk_1.diff.dcmp
# WARNING: File may have been truncated: actual file length (26667) is smaller than the expected size (28800) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (6961392) is smaller than the expected size (6963840) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (5416975) is smaller than the expected size (5417280) [astropy.io.fits.file]
# 2020oi.i.ut200204.3125_stch_1_i.2020oitmpl.18.stk_1.diff.dcmp
# 2020oi.r.ut200303.1098_stch_1_r.2020oitmpl.19.stk_1.diff.dcmp
# WARNING: File may have been truncated: actual file length (4804440) is smaller than the expected size (4806720) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (152024) is smaller than the expected size (152640) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (1374509) is smaller than the expected size (1376640) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (2442878) is smaller than the expected size (2445120) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (2499081) is smaller than the expected size (2499840) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (5730365) is smaller than the expected size (5731200) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (174556) is smaller than the expected size (175680) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (3789419) is smaller than the expected size (3790080) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (4414645) is smaller than the expected size (4415040) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (12544655) is smaller than the expected size (12545280) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (3351968) is smaller than the expected size (3352320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (9713529) is smaller than the expected size (9714240) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (4101514) is smaller than the expected size (4104000) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (194758) is smaller than the expected size (195840) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (7176104) is smaller than the expected size (7176960) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (261580) is smaller than the expected size (262080) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (6418787) is smaller than the expected size (6419520) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (5005165) is smaller than the expected size (5005440) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (1019414) is smaller than the expected size (1019520) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (9765585) is smaller than the expected size (9766080) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (10996359) is smaller than the expected size (10998720) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (7147872) is smaller than the expected size (7148160) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (10207439) is smaller than the expected size (10209600) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (6825677) is smaller than the expected size (6828480) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (187252) is smaller than the expected size (190080) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (7159268) is smaller than the expected size (7159680) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (11104615) is smaller than the expected size (11105280) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (4287994) is smaller than the expected size (4288320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (3611745) is smaller than the expected size (3614400) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (532235) is smaller than the expected size (532800) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (7726996) is smaller than the expected size (7727040) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (4949221) is smaller than the expected size (4950720) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (6113685) is smaller than the expected size (6114240) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (990927) is smaller than the expected size (993600) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (43243) is smaller than the expected size (46080) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (9334091) is smaller than the expected size (9336960) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (7445463) is smaller than the expected size (7447680) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (4254065) is smaller than the expected size (4256640) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (4156940) is smaller than the expected size (4158720) [astropy.io.fits.file]

# %%
fixed_optical_df = pd.concat(fixed_optical_df, ignore_index=True)
fixed_optical_df['time'] = timeArr
fixed_optical_df['zpt_av'] = zpts
fixed_optical_df['zpt_00'] = zpts00

fixed_optical_df['band'] = bands

# %%
plt.plot(fixed_optical_df['time'], fixed_optical_df['Mag'], 'o')

# %%
fixed_optical_df['mag0'] = -2.5*np.log10(fixed_optical_df['flux']) + fixed_optical_df['zpt_av']

# %%
plt.plot(fixed_optical_df['time'], fixed_optical_df['mag0'], 'o')

# %%
plt.figure(figsize=(8,6))
sns.set_context("talk")
sns.scatterplot('time', 'mag0', hue='band', data=fixed_optical_df)
plt.gca().invert_yaxis()

# %%
#dropping the failed points for now
fixed_optical_df = fixed_optical_df[fixed_optical_df['mag0'] > 0]

# %%
plt.figure(figsize=(8,6))
sns.set_context("talk")
sns.scatterplot('time', 'mag0', hue='band', data=fixed_optical_df)
plt.gca().invert_yaxis()
